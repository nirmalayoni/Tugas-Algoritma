# %%
#Ini adalah bagian awal cerita
Intro_07= print ("Halo Penyihir Muda! Kamu telah memasuki bagian gerbang perbatasan Kota Sihir Edenburgh!")
Spasi_07= print (" ") 
Intro_07= print ("Edenburgh sangat menantikan kehadiran penyihir baru, nikmatilah petualangan yang menyenangkan^-^")
Spasi_07= print (" ") 
Intro_07= print ("Sebelum memulai petualangan dan menjelajahi isi kota, mohon beritahu kami identitasmu dulu ya")
# Out:
# Halo Penyihir Muda! Kamu telah memasuki bagian gerbang perbatasan Kota Sihir Edenburgh!
#
# Edenburgh sangat menantikan kehadiran penyihir baru, nikmatilah petualangan yang menyenangkan^-^
#
# Sebelum memulai petualangan dan menjelajahi isi kota, mohon beritahu kami identitasmu dulu ya

# %%
#Ini adalah bagian membuat nama karakter
NamaDepan_07= input("Masukkan nama depanmu: ")
NamaBelakang_07= input("Masukkan marga keluargamu: ")
DaerahAsal_07= input("Masukkan daerah asalmu: ")
TanggalLahir_07= input("Masukkan tanggal kelahiranmu (lengkap): ")
Umur_07= input("Masukkan umurmu (angka): ")
#Disini saya menggunakan tipe data string karena semua masukan yang diminta ke pengguna berupa data tekstual

NamaLengkap_07= NamaDepan_07 + " " + NamaBelakang_07
Kelahiran_07= DaerahAsal_07 + ", " + TanggalLahir_07
#Lalu saya tidak perlu menggunakan str() pada variabel yang mau digabungkan dan diperlakukan sebagai string, karena setelah saya perhatikan, dari input() sudah menghasilkan string

Hasil_07= print("Berarti namamu " + NamaLengkap_07 + ". Kamu lahir di " + Kelahiran_07 + " dan sekarang umurmu " + Umur_07 + " tahun.")
Spasi_07= print(" ")
Welcome_07= print ("Selamat datang, " + NamaLengkap_07 + "!" + " Nikmatilah petualanganmu di Edenburgh yaa!")
#Terakhir saya menggunakan print() untuk menggunakan informasi yang telah dikumpulkan dan diformat sebagai string lengkap
# Out:
# Masukkan nama depanmu:  Hanni
# Masukkan marga keluargamu:  Pham
# Masukkan daerah asalmu:  Australia
# Masukkan tanggal kelahiranmu (lengkap):  23 Mei 2005
# Masukkan umurmu (angka):  19
# Berarti namamu Hanni Pham. Kamu lahir di Australia, 23 Mei 2005 dan sekarang umurmu 19 tahun.
#
# Selamat datang, Hanni Pham! Nikmatilah petualanganmu di Edenburgh yaa!

# %%
#Ini adalah bagian awal cerita
Prolog_07= print("Selamat datang di Akademi Sihir Hogweed!, senang bisa bertemu dengan kalian. Saya Albert Jeanne, kepala sekolah kalian disini, saya meyakini kalian akan lahir menjadi penyihir yang hebat. Selamat menikmati petualangan kalian!")
Spasi_07= print(" ") 

#Ini adalah bagian memecahkan sebuah pertanyaan bagian satu
Kelas_07= print("Di awal tahun pembelajaran, kamu mendapatkan kelas meracik ramuan. Prof.Snape terlihat galak, dia memberikan pertanyaan ke murid secara acak dan sekarang giliran kamu.") 
Spasi_07= print(" ")
Kasus_07= print(f"{NamaDepan_07},ini pertanyaan mudah bagi seorang penyihir, aku harap kamu bisa menjawab soal ini dengan cepat.")
#Disini saya menggunakan formatted string untuk mempermudah penulisan nilai variabel yang ingin dicetak pada perintah print
Pertanyaan_07= "Ramuan apa yang diminum jika ingin mendapatkan keberuntungan?"
JawabanBenar_07= "felix felicis"

#Ini bagian input jawaban dari pengguna
Spasi_07= print(" ")
JawabanPemain_07= input(f"{Pertanyaan_07} Jawabanmu adalah?: ")

#Ini bagian mengecek jawaban
#Saya menggunakan operator if dan strings methods berupa lower
if JawabanPemain_07.lower() == JawabanBenar_07:
    print(f"Bagus sekali,{NamaDepan_07}. Jawabanmu tepat.")
else:
    print(f"Sayang sekali {NamaDepan_07}, kamu perlu belajar lagi.")
# Out:
# Selamat datang di Akademi Sihir Hogweed!, senang bisa bertemu dengan kalian. Saya Albert Jeanne, kepala sekolah kalian disini, saya meyakini kalian akan lahir menjadi penyihir yang hebat. Selamat menikmati petualangan kalian!
#
# Di awal tahun pembelajaran, kamu mendapatkan kelas meracik ramuan. Prof.Snape terlihat galak, dia memberikan pertanyaan ke murid secara acak dan sekarang giliran kamu.
#
# Hanni,ini pertanyaan mudah bagi seorang penyihir, aku harap kamu bisa menjawab soal ini dengan cepat.
# Ramuan apa yang diminum jika ingin mendapatkan keberuntungan? Jawabanmu adalah?:  wedang jahe
# Sayang sekali Hanni, kamu perlu belajar lagi.

# %%
#ini bagian memecahkan sebuah pertanyaan bagian kedua
KelasKedua_07= print("Jam pelajaran telah berganti, saatnya kamu menghadapi Prof. McGonagall. Kali ini ada kuis mendadak dengan perolehan poin. Akankah kamu bisa menjawab dengan mudah?")
Spasi_07= print(" ")

#Ceritanya kuis
PertanyaanKuis_07= {"Apa warna favorit hantu Revenclaw?": "biru", 
                    "Apa nama orang yang bukan penyihir?": "muggle"}
#diatas merupakan bagian list di python yaitu merepresentasikan objek berupa pertanyaan kuis
Skor_07= 0

#bagian input jawaban dan mengecek jawaban pengguna, saya menggunakan operasi if dan for loop untuk memanggil isi list berupa pertanyaan dan jawaban
for Pertanyaan, Jawaban in PertanyaanKuis_07.items():
    JawabanPemain_07 = input(Pertanyaan).lower()
    if JawabanPemain_07 == Jawaban:
        print("Kamu benar!")
        Skor_07 += 1
    else:
        print("Kamu salah!")
        
Hasil_07= print(f"Skor akhir kamu adalah: {Skor_07}")
# Out:
# Jam pelajaran telah berganti, saatnya kamu menghadapi Prof. McGonagall. Kali ini ada kuis mendadak dengan perolehan poin. Akankah kamu bisa menjawab dengan mudah?
# Apa warna favorit hantu Revenclaw? biru
# Kamu benar!
# Apa nama orang yang bukan penyihir? muggle
# Kamu benar!
# Skor akhir kamu adalah: 2
