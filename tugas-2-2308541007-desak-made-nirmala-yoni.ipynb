# %%
Welcome_07= print ("---- UJIAN NINJA KELAS 1 ----") 

#di sini bagian mendeklarasikan variabel
Nama_Ninja_07= "Himawari"
Misi_07= "mengambil lonceng kakashi"
#Ada dua jenis nilai yang dinilai, yaitu skill dan kehadiran. Skill berupa strategi, kelincahan, kekuatan, dan serangan. 
Nilai_Kehadiran_07= 70
Nilai_Strategi_07= 86
Nilai_Kelincahan_07= 81
Nilai_Kekuatan_07= 68
Nilai_Serangan_07= 78
Total_Nilai_07= Nilai_Kehadiran_07 + Nilai_Strategi_07 + Nilai_Kelincahan_07 + Nilai_Kekuatan_07 + Nilai_Serangan_07
Rata_Rata_Nilai_07= Total_Nilai_07 / 5
Syarat_Lulus_07= 75

#ini bagian 2.4 Formatted Strings
Ninja_07= print(f"{Nama_Ninja_07} mengikuti misi {Misi_07}")

#ini bagian 2.5 Strings Index dan 2.6 Strings Methods
Inisial_Depan_07= Nama_Ninja_07[0]
Nama_Kapital_07= Nama_Ninja_07.upper()

#ini bagian 2.7 Operasi Matematika
Selisih_Nilai_Skill_Kehadiran_07= (Nilai_Strategi_07 + Nilai_Kelincahan_07 + Nilai_Kekuatan_07 + Nilai_Serangan_07) - Nilai_Kehadiran_07

#ini bagian 2.8 Operator Perbandingan
Lulus_Tes_Strategi_07= Nilai_Strategi_07 >= Syarat_Lulus_07
Lulus_Tes_Kelincahan_07= Nilai_Kelincahan_07 != Nilai_Strategi_07
Lulus_Tes_Kekuatan_07= Nilai_Kekuatan_07 < Nilai_Serangan_07

#lalu ini bagian 2.9 Operator Logika
Lulus_Ujian_07= (Rata_Rata_Nilai_07 >= Syarat_Lulus_07) and (Nilai_Serangan_07 < 75) 

#ini bagian menampilkan hasil
Hasil1_07= print(f"Inisial nama depan ninja : {Inisial_Depan_07}")
Hasil2_07= print(f"Nama ninja dalam huruf kapital : {Nama_Kapital_07}") 
Hasil3_07= print(f"Hasil selisih nilai antara skill dan kehadiran : {Selisih_Nilai_Skill_Kehadiran_07}") 
Hasil4_07= print(f"Lulus tes strategi : {Lulus_Tes_Strategi_07}") 
Hasil5_07= print(f"Lulus tes kelincahan : {Lulus_Tes_Kelincahan_07}") 
Hasil6_07= print(f"Lulus tes kekuatan : {Lulus_Tes_Kekuatan_07}") 
Hasil7_07= print(f"Lulus semua ujian : {Lulus_Ujian_07}")
# Out:
# ---- UJIAN NINJA KELAS 1 ----
# Himawari mengikuti misi mengambil lonceng kakashi
# Inisial nama depan ninja : H
# Nama ninja dalam huruf kapital : HIMAWARI
# Hasil selisih nilai antara skill dan kehadiran : 243
# Lulus tes strategi : True
# Lulus tes kelincahan : True
# Lulus tes kekuatan : True
# Lulus semua ujian : False
